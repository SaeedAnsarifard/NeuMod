# %%
from framework_chatgpt import FrameWork
#from survival_probablity import PseudoDirac
#from framework import BorexinoRecoilSpectrum
#from framework import SuperkPrediction

import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from cobaya.run import run

from getdist.mcsamples import MCSamplesFromCobaya
from getdist import plots, MCSamples
import getdist.plots as gdplt

plt.rcParams['text.usetex']=True
plt.style.use('classic')


frame          = FrameWork()

# %%
energy_obs = 
b8_unc = frame._compute_unoscilated_signal(frame.energy_recoil, frame.energy_nu, frame.spectrum_nu, 
                                           .energy_obs, self.cs_electron, self.resp_func)


# frame.distance = np.linspace(0.98,1.02,100)
# prediction     = frame[0.308,0,6.9e-5]

# %%
plt.errorbar(np.sqrt(frame.data[:,0]),frame.data[:,1],frame.data[:,2],frame.data[:,3],fmt='o')
plt.plot(frame.distance,prediction,ls='-',lw=2)

# %%
print(prediction/5.25)
# Out:
# [0.43812153 0.43776049 0.4373999  0.43703975 0.43668005 0.43632079
#  0.43596197 0.4356036  0.43524567 0.43488818 0.43453112 0.43417451
#  0.43381834 0.43346261 0.43310731 0.43275245 0.43239802 0.43204403
#  0.43169048 0.43133736 0.43098467 0.43063242 0.43028059 0.4299292
#  0.42957824 0.4292277  0.4288776  0.42852792 0.42817867 0.42782985
#  0.42748146 0.42713349 0.42678594 0.42643882 0.42609212 0.42574585
#  0.42539999 0.42505456 0.42470955 0.42436496 0.42402078 0.42367703
#  0.42333369 0.42299077 0.42264827 0.42230618 0.42196451 0.42162326
#  0.42128241 0.42094198 0.42060196 0.42026236 0.41992316 0.41958438
#  0.419246   0.41890804 0.41857048 0.41823333 0.41789659 0.41756026
#  0.41722433 0.4168888  0.41655368 0.41621897 0.41588466 0.41555075
#  0.41521724 0.41488413 0.41455143 0.41421912 0.41388721 0.41355571
#  0.4132246  0.41289388 0.41256357 0.41223365 0.41190413 0.411575
#  0.41124626 0.41091792 0.41058998 0.41026242 0.40993526 0.40960849
#  0.40928211 0.40895611 0.40863051 0.4083053  0.40798047 0.40765604
#  0.40733199 0.40700832 0.40668504 0.40636215 0.40603964 0.40571751
#  0.40539577 0.40507441 0.40475343 0.40443283]

# %%
# %%time

# for i in range(10):    
#     prediction = frame[0.319,0,7.54]
#     print(i)

# %%
# b = [[]for i in range (13)]
# for j in range (len(a)):
#     k = 0
#     for i in [1,3,5,7,9,11,13]:
#         #print(k)
#         if i >3 and i <11 :
#             b[k].append(np.abs(float(a[j].split('$')[i].split('{')[0][:-1])))
#             k +=1
#             b[k].append(np.abs(float(a[j].split('$')[i].split('{')[1][1:-2])))
#             k +=1
#             b[k].append(np.abs(float(a[j].split('$')[i].split('{')[2][1:-1])))
#             k +=1
#         else:
#             b[k].append(float(a[j].split('$')[i]))
#             #print(float(a[j].split('$')[i]))
#             k += 1
# b = np.array(b).T
# np.savetxt('./Data/final.txt',b,fmt='     '.join(['%1.2f']*12 + ['%1.3f']),header = 'E_min     E_max      '+
#            ' R_all    e_all+     e_all-      R_day     e_day+       e_day-     R_night      e_night+      '+
#            ' e_night-     B    hep')

# %%
frame = FrameWork()
error = frame.data[:,2]
data  = frame.data[:,1]

# %%
def LogLikelihood(t12,mum2,m12,delta):
    prediction = frame[t12,mum2,1e-5*m12]
    return -0.5*(np.sum(np.log10(2*np.pi*error**2) + ((1+delta)*prediction-data)**2/error**2))



info = {"likelihood": {"Chi2": LogLikelihood},
        
        "params": dict([("t12"  , {"prior" : {"min": 0.2, "max": 0.4},
                                  "latex" : r"\sin(\theta_{12})^2"  }),
                        
#                         ("mum2" , 0),
                        ("mum2" , {"prior" : {"min": 0, "max": 3},
                                   "latex" : r"\Delta m_{2}^2 \ \rm 10^{-11} \ eV^2"  }),
            
                        ("m12"  , {"prior" : {"dist": "norm", "loc": 7.54, "scale" : 0.2},
                                  "latex": r"\Delta m^2_{21} \ \rm 10^{-5} \ eV^2"  }),  
                        
                        ("delta", {"prior" : {"dist": "norm", "loc": 0, "scale" : 0.04},
                                  "latex": r"\delta"  })  
                        
                        
                        ]),
        
        "sampler": {"mcmc": {"Rminus1_stop": 0.001, "max_tries": 100000}}
       }

# %%
updated_info,sampler = run(info)
# Out:
# [chi2] Initialized external likelihood.
# [prior] *WARNING* There are unbounded parameters (['m12', 'delta']). Prior bounds are given at 0.9999995 confidence level. Beware of likelihood modes at the edge of the prior
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {Chi2: 103.0}
# [mcmc] Initial point: t12:0.3802694, mum2:1.990635, m12:7.452251, delta:-0.02999863
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-08-17 12:11:18 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.093
# [mcmc]  - Convergence of means: R-1 = 3.977914 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.169
# [mcmc]  - Convergence of means: R-1 = 0.472004 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.097545 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.230
# [mcmc]  - Convergence of means: R-1 = 0.139515 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.261
# [mcmc]  - Convergence of means: R-1 = 0.134144 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.079282 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.255
# [mcmc]  - Convergence of means: R-1 = 0.112513 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.253
# [mcmc]  - Convergence of means: R-1 = 0.107234 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.092587 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.253
# [mcmc]  - Convergence of means: R-1 = 0.099859 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.048428 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.248
# [mcmc]  - Convergence of means: R-1 = 0.055916 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.248
# [mcmc]  - Convergence of means: R-1 = 0.054066 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:12:18 : 9409 steps taken, and 2089 accepted.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.069521 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.242
# [mcmc]  - Convergence of means: R-1 = 0.063010 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.240
# [mcmc]  - Convergence of means: R-1 = 0.036967 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.242
# [mcmc]  - Convergence of means: R-1 = 0.050125 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.240
# [mcmc]  - Convergence of means: R-1 = 0.066508 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.241
# [mcmc]  - Convergence of means: R-1 = 0.044732 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.239
# [mcmc]  - Convergence of means: R-1 = 0.016860 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.238
# [mcmc]  - Convergence of means: R-1 = 0.022271 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.236
# [mcmc]  - Convergence of means: R-1 = 0.031065 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.234
# [mcmc]  - Convergence of means: R-1 = 0.043103 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.233
# [mcmc]  - Convergence of means: R-1 = 0.028584 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.025246 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.019563 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:13:18 : 18877 steps taken, and 4173 accepted.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.228
# [mcmc]  - Convergence of means: R-1 = 0.024938 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.227
# [mcmc]  - Convergence of means: R-1 = 0.023568 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.037657 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.033881 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4960 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.028149 after 3968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5120 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.023542 after 4096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.024033 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5440 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.029649 after 4352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5600 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.027775 after 4480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.031690 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5920 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.021627 after 4736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:14:23 : 28366 steps taken, and 6077 accepted.
# [mcmc] Learn + convergence test @ 6080 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.024236 after 4864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.016196 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6400 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.012730 after 5120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6560 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.019273 after 5248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.020853 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6880 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.033826 after 5504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7040 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.034288 after 5632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.026611 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7360 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.025600 after 5888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7520 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.019404 after 6016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.021926 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:15:23 : 36662 steps taken, and 7799 accepted.
# [mcmc] Learn + convergence test @ 7840 samples accepted.
# [mcmc]  - Acceptance rate: 0.211
# [mcmc]  - Convergence of means: R-1 = 0.014723 after 6272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8000 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.014223 after 6400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.012873 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8320 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.013534 after 6656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8480 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.013253 after 6784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.211
# [mcmc]  - Convergence of means: R-1 = 0.014166 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8800 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.012645 after 7040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8960 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.011856 after 7168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9120 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.017181 after 7296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9280 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.021986 after 7424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9440 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.018297 after 7552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9600 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.017614 after 7680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:16:23 : 45702 steps taken, and 9696 accepted.
# [mcmc] Learn + convergence test @ 9760 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.012502 after 7808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9920 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.016489 after 7936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10080 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.016331 after 8064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10240 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.015070 after 8192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10400 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.011517 after 8320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10560 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.008431 after 8448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10720 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.007713 after 8576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10880 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.007328 after 8704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11040 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.009340 after 8832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:19:35 : 52624 steps taken, and 11151 accepted.
# [mcmc] Learn + convergence test @ 11200 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.010418 after 8960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11360 samples accepted.
# [mcmc]  - Acceptance rate: 0.210
# [mcmc]  - Convergence of means: R-1 = 0.009054 after 9088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11520 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.010387 after 9216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11680 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.008142 after 9344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11840 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.009404 after 9472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12000 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.008406 after 9600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12160 samples accepted.
# [mcmc]  - Acceptance rate: 0.208
# [mcmc]  - Convergence of means: R-1 = 0.010391 after 9728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12320 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.007158 after 9856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12480 samples accepted.
# [mcmc]  - Acceptance rate: 0.208
# [mcmc]  - Convergence of means: R-1 = 0.007870 after 9984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12640 samples accepted.
# [mcmc]  - Acceptance rate: 0.208
# [mcmc]  - Convergence of means: R-1 = 0.010582 after 10112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 
 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:47:37 : 321450 steps taken, and 65896 accepted.
# [mcmc] Learn + convergence test @ 65920 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002096 after 52736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66080 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002040 after 52864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66240 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002099 after 52992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66400 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002033 after 53120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66560 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002059 after 53248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66720 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002231 after 53376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 66880 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002128 after 53504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 67040 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002089 after 53632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 67200 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002115 after 53760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 67360 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002203 after 53888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 67520 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002425 after 54016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 67680 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002568 after 54144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:48:37 : 330412 steps taken, and 67774 accepted.
# [mcmc] Learn + convergence test @ 67840 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002483 after 54272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68000 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002386 after 54400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68160 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002388 after 54528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68320 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002431 after 54656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68480 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.002159 after 54784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68640 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001745 after 54912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68800 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001814 after 55040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 68960 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001771 after 55168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 69120 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001649 after 55296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 69280 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001280 after 55424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 69440 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.001210 after 55552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 69600 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.000872 after 55680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-17 12:49:37 : 340068 steps taken, and 69744 accepted.
# [mcmc] Learn + convergence test @ 69760 samples accepted.
# [mcmc]  - Acceptance rate: 0.204
# [mcmc]  - Convergence of means: R-1 = 0.000989 after 55808 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.026177 after 69760 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 69760 accepted steps.

# %%
# Filled 2D comparison plot with legend
gd_sample = MCSamplesFromCobaya(updated_info, sampler.products()["sample"])

gdplot = gdplt.get_subplot_plotter(width_inch=7)

gdplot.settings.scaling = False
gdplot.triangle_plot(gd_sample, ["t12","m12","delta","mum2"], filled=True, 
                     param_limits={'t12': (0.2, 0.4), 
                                   'm12': (7, 8),
                                   'delta': (-0.2, 0.2),
                                   'mum2': (0, 1.5)
                                  },lw=2)

#gdplot.export('./bayes_1_nopriors.pdf')

# %%
# #plt.plot(frame.day,total_event,'.')
# print(frame.borom_unoscilated_total)
# plt.plot(np.mod(frame.data[:,0],365.25)/365.25,frame.data[:,3],'.')

# %%
flux,dist,day = SuperkPrediction(frame.data,frame.total_days,total_event,frame.distance,frame.day)

# %%
plt.xlim(0.94,1.06)
plt.plot(frame.distance**2,0.44*total_event,'b-')
#plt.plot(frame.data[:,6],frame.data[:,3],'g.')
plt.plot(frame.data[:,6],0.44*flux,'ro')

# %%
#plt.xlim(0,500)
#plt.plot(np.arange(0,frame.total_days,1),frame.distance**2)
#plt.plot(frame.data[:,0],frame.data[:,6],'g.')
#plt.plot(frame.data[:,0],dpredict**2,'r.')

plt.plot(frame.data[:,6],dist**2,'.')

# %%
plt.plot(frame.day,0.44*total_event,'b.')
#plt.plot(lpredict,frame.data[:,3],'.')
plt.plot(day,0.44*flux,'go')

# %%
print(frame.data[(lpredict>1)&(lpredict<2)&(0.44*bin_predict>2.3),:])
# Out:
# [[5.53154815e+02 2.42537037e+00 2.48776620e+00 2.37000000e+00
#   2.60000000e-01 2.80000000e-01 9.94000000e-01 2.35600000e+00
#   2.63000000e-01 2.81000000e-01]
#  [9.18720139e+02 2.49046296e+00 2.49025463e+00 2.29000000e+00
#   3.20000000e-01 3.00000000e-01 9.94000000e-01 2.27700000e+00
#   3.20000000e-01 2.96000000e-01]
#  [2.38007956e+03 2.49901620e+00 2.49943287e+00 2.20000000e+00
#   3.30000000e-01 3.00000000e-01 9.94000000e-01 2.19100000e+00
#   3.26000000e-01 3.02000000e-01]]

# %%
plt.plot(frame.distance,frame.day,'.')
plt.plot(dist,day,'o')
