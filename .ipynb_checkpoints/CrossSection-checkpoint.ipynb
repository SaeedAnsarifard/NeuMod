# %%
from framework_chatgpt import FrameWork
#from survival_probablity import PseudoDirac
#from framework import BorexinoRecoilSpectrum
#from framework import SuperkPrediction

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from scipy import interpolate
from cobaya.run import run

from getdist.mcsamples import MCSamplesFromCobaya
from getdist import plots, MCSamples
import getdist.plots as gdplt

plt.rcParams['text.usetex']=True
plt.style.use('classic')

# %%
frame          = FrameWork(resolution_correction=False, masked_val=0.1)
spectrum = frame.spectrum_nu

signal_efficiency = np.array(pd.read_csv('./signal_efficiency.csv'))

signal_efficiency_interpolation = interpolate.interp1d(signal_efficiency[:,0], 
                                                       signal_efficiency[:,1],
                                                       bounds_error=False,fill_value=(0,90))

# %%
energy_obs = np.array([[4.5,19.5]])
e_neutrino = frame.energy_nu
t_recoil   = frame.energy_recoil
resp_func  = frame._response_function(energy_obs, t_recoil)

for i in range (len(energy_obs)):
    plt.plot(frame.energy_recoil,resp_func[i])

# %%
electron_cross_section = frame._compute_cross_section(e_neutrino,t_recoil,1)
moun_cross_section = frame._compute_cross_section(e_neutrino,t_recoil,-1)

signal_efficiency = signal_efficiency_interpolation(t_recoil)

# %%
integral_electron = np.zeros(len(t_recoil))
integral_moun = np.zeros(len(t_recoil))
for i in range (len(t_recoil)):
    integral_electron[i] = np.trapz(spectrum[i:]*electron_cross_section[i,i:],e_neutrino[i:])
    integral_moun[i] = np.trapz(spectrum[i:]*moun_cross_section[i,i:],e_neutrino[i:])

# %%
plt.xlim(1,15)
#plt.xscale('log')
plt.plot(t_recoil,resp_func[0]*0.01*signal_efficiency*integral_electron,'b-')
plt.plot(t_recoil,resp_func[0]*0.01*signal_efficiency*integral_moun,'r-')

plt.plot(t_recoil,0.01*signal_efficiency*integral_electron,'b:')
plt.plot(t_recoil,0.01*signal_efficiency*integral_moun,'r:')

plt.plot(t_recoil,integral_electron,'b--')
plt.plot(t_recoil,integral_moun,'r--')

# %%
print(np.trapz(integral_electron,t_recoil))
print(np.trapz(resp_func[0]*0.01*signal_efficiency*integral_electron,t_recoil))
# Out:
# 59.80034694311202
# 16.6532505800314

# %%
plt.ticklabel_format(useOffset=False)
plt.errorbar(np.sqrt(frame.data[:,0]),frame.data[:,1]/2.31 - 1,frame.data[:,2]/2.31,frame.data[:,3],fmt='o')
plt.plot(frame.distance,prediction/np.mean(prediction) - 1,ls='-',lw=2)

# %%
cond = frame.distance <1
print(np.trapz(prediction[cond]/np.mean(prediction) - 1 , frame.distance[cond] ))


cond = frame.distance >1
print(np.trapz(prediction[cond]/np.mean(prediction) - 1 , frame.distance[cond] ))
# Out:
# 0.0003998784056612236
# -0.0004000336667680753

# %%
mean_data = np.mean(frame.data[:,1])
mean_data = 2.31

cond = np.sqrt(frame.data[:,0]) < 1
print(np.trapz(frame.data[cond,1]/mean_data - 1, np.sqrt(frame.data[cond,0])))


cond = np.sqrt(frame.data[:,0]) > 1
print(np.trapz(frame.data[cond,1]/mean_data - 1, np.sqrt(frame.data[cond,0])))
# Out:
# 0.0004616794997271423
# 0.00016149587292004606

# %%
frame = FrameWork(resolution_correction=False, masked_val=0.1)
error = frame.data[:,2]
data  = frame.data[:,1]

# %%
def LogLikelihood(t12,mum2,m12,delta):
    prediction = frame[t12,mum2,1e-5*m12]
    return -0.5*(np.sum(np.log10(2*np.pi*error**2) + ((1+delta)*prediction-data)**2/error**2))



info = {"likelihood": {"Chi2": LogLikelihood},
        
        "params": dict([("t12"  , {"prior" : {"min": 0.28, "max": 0.36},
                                  "latex" : r"\sin(\theta_{12})^2"  }),
                        
#                         ("mum2" , 0),
                        ("mum2" , {"prior" : {"min": 0, "max": 3},
                                   "latex" : r"\Delta m_{2}^2 \ \rm 10^{-11} \ eV^2"  }),
            
                        ("m12"  , {"prior" : {"dist": "norm", "loc": 7.54, "scale" : 0.2},
                                  "latex": r"\Delta m^2_{21} \ \rm 10^{-5} \ eV^2"  }),  
                        
                        ("delta", {"prior" : {"dist": "norm", "loc": 0, "scale" : 0.04},
                                  "latex": r"\delta"  })  
                        
                        
                        ]),
        
        "sampler": {"mcmc": {"Rminus1_stop": 0.001, "max_tries": 100000}}
       }

# %%
updated_info,sampler = run(info)
# Out:
# [chi2] Initialized external likelihood.
# [prior] *WARNING* There are unbounded parameters (['m12', 'delta']). Prior bounds are given at 0.9999995 confidence level. Beware of likelihood modes at the edge of the prior
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {Chi2: 73.3}
# [mcmc] Initial point: t12:0.3527306, mum2:0.5973797, m12:7.642612, delta:0.04912662
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-08-18 23:08:10 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.087
# [mcmc]  - Convergence of means: R-1 = 5.956075 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.166
# [mcmc]  - Convergence of means: R-1 = 0.816439 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.202
# [mcmc]  - Convergence of means: R-1 = 0.402647 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.569038 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.232
# [mcmc]  - Convergence of means: R-1 = 0.230674 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.062999 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.063024 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.211
# [mcmc]  - Convergence of means: R-1 = 0.035927 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:09:10 : 7627 steps taken, and 1421 accepted.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.211
# [mcmc]  - Convergence of means: R-1 = 0.046811 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.071848 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.211
# [mcmc]  - Convergence of means: R-1 = 0.035468 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.064157 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.030664 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.022720 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.032473 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.037705 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.028403 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.024339 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.026915 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:10:10 : 15314 steps taken, and 3138 accepted.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.021946 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.045313 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.039734 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.033153 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.034506 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.016768 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.017065 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.013306 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.029887 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.027449 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.032183 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:11:10 : 22952 steps taken, and 4840 accepted.
# [mcmc] Learn + convergence test @ 4960 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.024879 after 3968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5120 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.029942 after 4096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.019060 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5440 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.017160 after 4352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5600 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.005851 after 4480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.009116 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5920 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.006382 after 4736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6080 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.005731 after 4864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.007642 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6400 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.006663 after 5120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:12:10 : 30620 steps taken, and 6552 accepted.
# [mcmc] Learn + convergence test @ 6560 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.009129 after 5248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.011704 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6880 samples accepted.
# [mcmc]  - Acceptance rate: 0.224
# [mcmc]  - Convergence of means: R-1 = 0.010815 after 5504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7040 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.012367 after 5632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.222
# [mcmc]  - Convergence of means: R-1 = 0.013577 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7360 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.011327 after 5888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7520 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.013414 after 6016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.010160 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7840 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.017415 after 6272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8000 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.016512 after 6400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.016976 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:13:10 : 38422 steps taken, and 8196 accepted.
# [mcmc] Learn + convergence test @ 8320 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.015504 after 6656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8480 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.016078 after 6784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.012849 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8800 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.012052 after 7040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8960 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.017519 after 7168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9120 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.015561 after 7296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9280 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.011097 after 7424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9440 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.007921 after 7552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9600 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.007313 after 7680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9760 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.010336 after 7808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:14:10 : 46070 steps taken, and 9812 accepted.
# [mcmc] Learn + convergence test @ 9920 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.014051 after 7936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10080 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.013280 after 8064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10240 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.009291 after 8192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10400 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.011917 after 8320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10560 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.015452 after 8448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10720 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.010477 after 8576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10880 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.012620 after 8704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11040 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.010783 after 8832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11200 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.015527 after 8960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11360 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.014087 after 9088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:15:10 : 53714 steps taken, and 11442 accepted.
# [mcmc] Learn + convergence test @ 11520 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.010999 after 9216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11680 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.008647 after 9344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11840 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.008742 after 9472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12000 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.010347 after 9600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12160 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.007366 after 9728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12320 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.008881 after 9856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12480 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.008247 after 9984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12640 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.004671 after 10112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12800 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.005546 after 10240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12960 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.005035 after 10368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13120 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.007272 after 10496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-18 23:16:10 : 61280 steps taken, and 13146 accepted.
# [mcmc] Learn + convergence test @ 13280 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.005953 after 10624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13440 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.007188 after 10752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13600 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.007971 after 10880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13760 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.008696 after 11008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13920 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.
samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002448 after 32640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 40960 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002740 after 32768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41120 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002767 after 32896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41280 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002857 after 33024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41440 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002871 after 33152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41600 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002962 after 33280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41760 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002687 after 33408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 41920 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002901 after 33536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 42080 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002427 after 33664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 42240 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002119 after 33792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-08-19 01:26:29 : 196893 steps taken, and 42397 accepted.
# [mcmc] Learn + convergence test @ 42400 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002010 after 33920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 42560 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.001961 after 34048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 42720 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002023 after 34176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 42880 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002208 after 34304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 43040 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002260 after 34432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 43200 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.002360 after 34560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 updated_info,sampler = run(info)
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/run.py:155, in run(info_or_yaml_or_file, packages_path, output, debug, stop_at_error, resume, force, minimize, no_mpi, test, override)
#     153                 return updated_info, sampler
#     154             # Run the sampler
# --> 155             sampler.run()
#     156 return updated_info, sampler
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/samplers/mcmc/mcmc.py:364, in MCMC.run(self)
#     362 with mpi.ProcessState(self) as state:
#     363     while last_n < self.max_samples and not self.converged:
# --> 364         self.get_new_sample()
#     365         self.n_steps_raw += 1
#     366         if self.output_every.unit:
#     367             # if output_every in sec, print some info
#     368             # and dump at fixed time intervals
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/samplers/mcmc/mcmc.py:441, in MCMC.get_new_sample_metropolis(self)
#     439 trial = self.current_point.values.copy()
#     440 self.proposer.get_proposal(trial)
# --> 441 trial_results = self.model.logposterior(trial)
#     442 accept = self.metropolis_accept(trial_results.logpost, self.current_point.logpost)
#     443 self.process_accept_or_reject(accept, trial, trial_results)
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/model.py:558, in Model.logposterior(self, params_values, as_dict, make_finite, return_derived, cached, _no_check)
#     555         logpriors.extend(self.prior.logps_external(input_params))
#     556 if -np.inf not in logpriors:
#     557     # noinspection PyUnboundLocalVariable
# --> 558     like = self._loglikes_input_params(input_params,
#     559                                        return_derived=return_derived,
#     560                                        cached=cached, make_finite=make_finite)
#     561     loglikes, derived_sampler = like if return_derived else (like, [])
#     562 else:
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/model.py:378, in Model._loglikes_input_params(self, input_params, return_derived, return_output_params, as_dict, make_finite, cached)
#     376 depend_list = [input_params[p] for p in param_dep]
#     377 params = {p: input_params[p] for p in component.input_params}
# --> 378 compute_success = component.check_cache_and_compute(
#     379     params, want_derived=need_derived,
#     380     dependency_params=depend_list, cached=cached)
#     381 if not compute_success:
#     382     loglikes[:] = -np.inf
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/theory.py:253, in Theory.check_cache_and_compute(self, params_values_dict, dependency_params, want_derived, cached)
#     251     self.timer.start()
#     252 try:
# --> 253     if self.calculate(state, want_derived, **params_values_dict) is False:
#     254         return False
#     255 except always_stop_exceptions:
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/likelihood.py:128, in Likelihood.calculate(self, state, want_derived, **params_values_dict)
#     126 derived: Optional[ParamValuesDict] = {} if want_derived else None
#     127 state["logp"] = -np.inf  # in case of exception
# --> 128 state["logp"] = self.logp(_derived=derived, **params_values_dict)
#     129 self.log.debug("Computed log-likelihood = %g", state["logp"])
#     130 if derived is not None:
#
# File ~/miniconda3/envs/BaseCamp/lib/python3.9/site-packages/cobaya/likelihood.py:193, in LikelihoodExternalFunction.logp(self, **params_values)
#     191     params_values[self._self_arg] = self
#     192 try:
# --> 193     return_value = self.external_function(**params_values)
#     194 except:
#     195     self.log.debug("External function failed at evaluation.")
#
# Input In [13], in LogLikelihood(t12, mum2, m12, delta)
#       1 def LogLikelihood(t12,mum2,m12,delta):
# ----> 2     prediction = frame[t12,mum2,1e-5*m12]
#       3     return -0.5*(np.sum(np.log10(2*np.pi*error**2) + ((1+delta)*prediction-data)**2/error**2))
#
# File ~/Documents/GitHub/NeuMod/framework_chatgpt.py:111, in FrameWork.__getitem__(self, param_update)
#     109         r[:,z] = np.trapz(self.spectrum_nu * (self.cs_electron[z,:] * survival_prob + self.cs_muon[z,:] * (1 - survival_prob - sterile_prob)), self.energy_nu, axis=1) - np.trapz(self.spectrum_nu[:z] * (self.cs_electron[z,:z] * survival_prob[:,:z] + self.cs_muon[z,:z] * (1 - survival_prob[:,:z] - sterile_prob[:,:z])), self.energy_nu[:z], axis=1)
#     110     else:
# --> 111         r[:,z] = np.trapz(self.spectrum_nu[z:] * (self.cs_electron[z,z:] * survival_prob[:,z:] + self.cs_muon[z,z:] * (1 - survival_prob[:,z:] - sterile_prob[:,z:])), self.energy_nu[z:],axis=1)
#     113 if self.resolution_correction:
#     114     self.flux_fraction_prediction = (self.norm/self.borom_unoscilated_total) * np.trapz( r * self.resp_func,self.energy_recoil, axis=1)/self.distance**2
#
# KeyboardInterrupt:

# %%
# Filled 2D comparison plot with legend
gd_sample = MCSamplesFromCobaya(updated_info, sampler.products()["sample"])

gdplot = gdplt.get_subplot_plotter(width_inch=7)

gdplot.settings.scaling = False
gdplot.triangle_plot(gd_sample, ["t12","m12","delta","mum2"], filled=True, 
                     param_limits={'t12': (0.28, 0.36), 
                                   'm12': (7, 8),
                                   'delta': (-0.2, 0.2),
                                   'mum2': (0, 1.5)
                                  },lw=2)

#gdplot.export('./bayes_1_nopriors.pdf')

# %%
#best fit and covariance matrix and errors
mean   = gd_sample.getMeans()
covmat = gd_sample.getCovMat().matrix[:, :]
print("Mean:")
print(mean)
print("Covariance matrix:")
print(covmat)
print('####################')

stats = gd_sample.getMargeStats()
lims1 = stats.parWithName('t12').limits
lims2 = stats.parWithName('mum2').limits
lims3 = stats.parWithName('m12').limits
lims4 = stats.parWithName('delta').limits

for conf, lim1, lim2, lim3, lim4 in zip(gd_sample.contours, lims1,lims2,lims3,lims4):
    print('t12 %s%% lower: %.1f upper: %.1f (%s)'%(conf, lim1.lower, lim1.upper, lim1.limitType()))
    print('mum2 %s%% lower: %.2f upper: %.2f (%s)'%(conf, lim2.lower, lim2.upper, lim2.limitType()))
    print('m12 %s%% lower: %.2f upper: %.2f (%s)'%(conf, lim3.lower, lim3.upper, lim3.limitType()))
    print('delta %s%% lower: %.2f upper: %.2f (%s)'%(conf, lim3.lower, lim3.upper, lim3.limitType()))
    print('####################')
